# %%
from modelclass import model

# %%
midn,baseline = model.modelload('data/idn',run=True,keep='Baseline')
# Out:
# file read:  C:\modelflow manual raw models\idn\data\idn.pcim

# %%
for oilshock in [10, 20 , 30]:
    print(f'Simulate oil shock: {oilshock}')
    oilshockdf = baseline.upd(f'<2025 2100> WLDFCRUDE_PETRO + {oilshock}')
    tempdf = midn(oilshockdf,2024,2100,silent=1,keep=f'Oilshock =  {oilshock}')
# Out:
# Simulate oil shock: 10
# Simulate oil shock: 20
# Simulate oil shock: 30

# %%
midn['#Headline'].names
# Out:
# ['IDNGDPPCKN', 'IDNLMEMPTOTL', 'IDNBFBOPTOTLCD', 'IDNFPCPITOTLXN']

# %%
midn.keep_plot('#Headline',diff=True,samefig=1);

# %%
midn.keep_plot('#Headline',diffpct=True,samefig=1);

# %%
midn.keep_show(use_smpl=1)

# %%
baseline.index
# Out:
# Int64Index([1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990,
#             1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001,
#             2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012,
#             2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023,
#             2024, 2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034,
#             2035, 2036, 2037, 2038, 2039, 2040, 2041, 2042, 2043, 2044, 2045,
#             2046, 2047, 2048, 2049, 2050],
#            dtype='int64')
