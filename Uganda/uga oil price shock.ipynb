# %%
from modelclass import model

# %%
midn,baseline = model.modelload('data/idn',run=True,keep='Baseline')
# Out:
# file read:  C:\modelflow manual raw models\idn\data\idn.pcim

# %%
for oilshock in [10, 20 , 30]:
    print(f'Simulate oil shock: {oilshock}')
    oilshockdf = baseline.upd(f'<2025> WLDFCRUDE_PETRO + {oilshock}')
    tempdf = midn(oilshockdf,silent=1,keep=f'Oilshock =  {oilshock}')
# Out:
# Simulate oil shock: 10
# Simulate oil shock: 20
# Simulate oil shock: 30

# %%
lookat =  midn['#Headline'].names + ['idnREER  IDNCCEMISCO2* IDNCCEMISCO2TKN WLDFCRUDE_PETRO']

# %%
figs = midn.keep_plot(lookat,diffpct=True,samefig=1,title='Indonesia: Impact of oilshock',legend=1);
